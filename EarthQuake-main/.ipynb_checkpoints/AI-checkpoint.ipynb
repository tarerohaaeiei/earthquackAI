# %%
# !pip install numpy pandas seaborn matplotlib scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 23.5 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 23.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv('~/Documents/EarthQuake/Earthquake-Intensity-dataset.csv')

# %%
df
# Out:
#       Magnitude  Depth  destruction  Victim's reaction  Intensity
# 0           7.1   40.0            6                  7          8
# 1           7.7   23.5            6                  7          8
# 2           7.7  196.0            4                  5          6
# 3           6.9   15.0            3                  4          5
# 4           6.9   51.6            4                  5          6
# ...         ...    ...          ...                ...        ...
# 9995        6.7   15.0            7                  8          9
# 9996        6.5   16.7            5                  6          7
# 9997        7.8   60.0            6                  7          8
# 9998        5.0   28.0            0                  1          2
# 9999        6.5    2.7            6                  7          8
#
# [10000 rows x 5 columns]

# %%
train_size = 0.8
num = int(len(df) * train_size)

train_data = df.sample(n=num, random_state=42)

train_data.to_csv("train_data.csv", index=False)

# %%
train_data
# Out:
#       Magnitude    Depth  destruction  Victim's reaction  Intensity
# 6252        6.9   93.000            4                  5          6
# 4684        7.0   73.000            5                  6          7
# 1731        6.9  205.681            3                  4          5
# 4742        5.7   10.000            5                  6          7
# 4521        5.5   10.000            6                  7          8
# ...         ...      ...          ...                ...        ...
# 1638        6.5   33.000            5                  6          7
# 5891        6.9   25.000            2                  3          4
# 7427        6.4   13.000            7                  8          9
# 608         7.3   10.000            6                  7          8
# 6907        6.6   85.000            6                  7          8
#
# [8000 rows x 5 columns]

# %%
test_size = 0.2
num = int(len(df) * test_size)

test_data = df.drop(train_data.index).sample(n=num, random_state=42)

test_data.to_csv("test_data.csv", index=False)

# %%
test_data
# Out:
#       Magnitude  Depth  destruction  Victim's reaction  Intensity
# 9306        6.7   17.0            4                  5          6
# 1796        6.7   33.0            4                  5          6
# 6783        6.9  145.0            3                  4          5
# 4599        7.6   50.0            4                  5          6
# 6573        7.1  125.6            5                  6          7
# ...         ...    ...          ...                ...        ...
# 5750        8.2   47.4            7                  8          9
# 6609        5.6   15.0            6                  7          8
# 4388        6.8   26.0            5                  6          7
# 7294        7.9   40.0            6                  7          8
# 5732        7.1  434.0            4                  5          6
#
# [2000 rows x 5 columns]

# %%
X = train_data.drop(columns=['Intensity'])
Y = train_data['Intensity']
x = test_data.drop(columns=['Intensity'])
y = test_data['Intensity']

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X)
x_test_scaled = scaler.transform(x)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, Y)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test_scaled)
accuracy = accuracy_score(y, y_pred)
print("Test set accuracy:", accuracy)
# Out:
# Test set accuracy: 0.9985

# %%
prediction = knn.predict(X_train_scaled)
accuracy = accuracy_score(Y, prediction)
print("Train Set Accuracy:", accuracy)
# Out:
# Train Set Accuracy: 0.999

# %%
predictions = np.concatenate((prediction, y_pred))
labels = np.concatenate((Y, y))

overall_accuracy = accuracy_score(labels, predictions)
print("Overall Accuracy:", overall_accuracy)
# Out:
# Overall Accuracy: 0.9989

# %%
report = classification_report(y, y_pred)

print("\nClassification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.33      1.00      0.50         1
#            2       1.00      0.80      0.89        10
#            3       1.00      1.00      1.00        54
#            4       1.00      1.00      1.00       150
#            5       1.00      1.00      1.00       220
#            6       1.00      1.00      1.00       403
#            7       1.00      1.00      1.00       489
#            8       1.00      1.00      1.00       305
#            9       1.00      1.00      1.00       224
#           10       1.00      1.00      1.00       114
#           11       1.00      1.00      1.00        24
#           12       1.00      1.00      1.00         6
#
#     accuracy                           1.00      2000
#    macro avg       0.94      0.98      0.95      2000
# weighted avg       1.00      1.00      1.00      2000

# %%
def predict_earthquake_intensity(input_parameters):
    """
    Predicts the earthquake intensity and prints the description based on the predicted intensity.

    Parameters:
    input_parameters (list): List of input values [Magnitude, Depth, Destruction, Victim's Reaction]
    """
    
    # Assuming the scaler and knn are already defined and fitted globally
    input_parameters = [input_parameters]
    
    # Scale the input parameters
    input_parameters_scaled = scaler.transform(input_parameters)
    
    # Predict the earthquake intensity
    predicted_intensity = knn.predict(input_parameters_scaled)
    
    # Print the predicted intensity value
    print(f"Predicted Intensity: {predicted_intensity[0]}")
    
    # Return the description based on the predicted intensity value
    intensity_descriptions = {
        1: "I. Not felt. Marginal and long-period effects of large earthquakes.",
        2: "II. Felt by persons at rest, on upper floors, or otherwise favorably placed to sense tremors.",
        3: "III. Felt indoors. Hanging objects swing. Vibrations are similar to those caused by the passing of light trucks. Duration can be estimated.",
        4: "IV. Vibrations are similar to those caused by the passing of heavy trucks (or a jolt similar to that caused by a heavy ball striking the walls). Standing automobiles rock. Windows, dishes, doors rattle. Glasses clink, crockery clashes. In the upper range of grade IV, wooden walls and frames creak.",
        5: "V. Felt outdoors; direction may be estimated. Sleepers awaken. Liquids are disturbed, some spilled. Small objects are displaced or upset. Doors swing, open, close. Pendulum clocks stop, start, change rate.",
        6: "VI. Felt by all; many are frightened and run outdoors. Persons walk unsteadily. Pictures fall off walls. Furniture moves or overturns. Weak plaster and masonry cracks. Small bells ring (church, school). Trees, bushes shake.",
        7: "VII. Difficult to stand. Noticed by drivers of automobiles. Hanging objects quivering. Furniture broken. Damage to weak masonry. Weak chimneys broken at roof line. Fall of plaster, loose bricks, stones, tiles, cornices.",
        8: "VIII. Steering of automobiles affected. Damage to masonry; partial collapse. Some damage to reinforced masonry; none to reinforced masonry designed to resist lateral forces.",
        9: "IX. General panic. Weak masonry destroyed; ordinary masonry heavily damaged, sometimes with complete collapse.",
        10: "X. Most masonry and frame structures destroyed with their foundations. Some well-built wooden structures and bridges destroyed.",
        11: "XI. Rails bent greatly. Underground pipelines completely out of service.",
        12: "XII. Damage nearly total. Large rock masses displaced. Lines of sight and level distorted. Objects thrown into air."
    }

    # Get the description based on the predicted intensity
    description = intensity_descriptions.get(predicted_intensity[0], "Unknown intensity.")
    
    # Print the description
    print(description)
    
    return predicted_intensity[0], description

# %%
def get_user_input():
    """
    Prompts the user to input the required parameters for earthquake prediction.
    Magnitude and Depth are required, while Destruction and Victim's Reaction are optional.
    
    Returns:
        input_parameters (list): A list of input values [Magnitude, Depth, Destruction, Victim's Reaction]
    """
    try:
        magnitude = float(input("Enter Magnitude: "))
        depth = float(input("Enter Depth (km): "))
        
        # Optional inputs for Destruction and Victim's Reaction with default values
        destruction = input("Enter Destruction level (1-10) [default: 5]: ") or 5
        destruction = int(destruction)
        
        reaction = input("Enter Victim's Reaction level (1-10) [default: 5]: ") or 5
        reaction = int(reaction)
        
    except ValueError:
        print("Invalid input. Please enter valid numbers for each parameter.")
        return None

    return [magnitude, depth, destruction, reaction]

# %%
    while True:
        input_parameters = get_user_input()
        if input_parameters is None:
            continue  # If invalid input, ask again

        # Assuming scaler and knn are defined globally
        input_parameters_scaled = scaler.transform([input_parameters])
        predicted_intensity = knn.predict(input_parameters_scaled)[0]
        
        print(f"Predicted Intensity: {predicted_intensity}")
        print(intensity_descriptions.get(predicted_intensity, "Unknown intensity."))
        print("-" * 50)  # Separator between entries
        
        # Ask if the user wants to input another set of parameters
        another = input("Would you like to predict another earthquake intensity? (yes/no): ").strip().lower()
        if another != 'yes':
            break

# Run the prediction with user input
predict_earthquake_intensity_from_user_input()
# Out:
# Enter Magnitude:  8
# Enter Depth (km):  100
# Enter Destruction level (1-10):  1
# Enter Victim's Reaction level (1-10):  1
# Predicted Intensity: 3
# /Users/11.anx_/micromamba/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 11
#       8 predicted_intensity = knn.predict(input_parameters_scaled)[0]
#      10 print(f"Predicted Intensity: {predicted_intensity}")
# ---> 11 print(intensity_descriptions.get(predicted_intensity, "Unknown intensity."))
#      12 print("-" * 50)  # Separator between entries
#      14 # Ask if the user wants to input another set of parameters
#
# NameError: name 'intensity_descriptions' is not defined
